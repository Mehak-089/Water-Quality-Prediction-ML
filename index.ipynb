# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
water_data=pd.read_csv('water_data.csv')
water_data.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (�mhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
print(water_data.describe(include='all'))
# Out:
#        STATION CODE LOCATIONS STATE  Temp D.O. (mg/l)    PH  \
# count          1991      1991  1991  1991        1991  1991
# unique          321       666   203   179         166   266
# top             NAN       NAN   NAN    28         6.8   7.2
# freq            122       184   761   241         118   138
# mean            NaN       NaN   NaN   NaN         NaN   NaN
# std             NaN       NaN   NaN   NaN         NaN   NaN
# min             NaN       NaN   NaN   NaN         NaN   NaN
# 25%             NaN       NaN   NaN   NaN         NaN   NaN
# 50%             NaN       NaN   NaN   NaN         NaN   NaN
# 75%             NaN       NaN   NaN   NaN         NaN   NaN
# max             NaN       NaN   NaN   NaN         NaN   NaN
#
#        CONDUCTIVITY (�mhos/cm) B.O.D. (mg/l) NITRATENAN N+ NITRITENANN (mg/l)  \
# count                     1991          1991                             1991
# unique                    1005           408                              507
# ...

# %%
water_data.columns
# Out:
# Index(['STATION CODE', 'LOCATIONS', 'STATE', 'Temp', 'D.O. (mg/l)', 'PH',
#        'CONDUCTIVITY (�mhos/cm)', 'B.O.D. (mg/l)',
#        'NITRATENAN N+ NITRITENANN (mg/l)', 'FECAL COLIFORM (MPN/100ml)',
#        'TOTAL COLIFORM (MPN/100ml)Mean', 'year'],
#       dtype='object')

# %%
water_data.shape
# Out:
# (1991, 12)

# %%
water_data.dtypes
# Out:
# STATION CODE                        object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (�mhos/cm)             object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %%
water_data.describe(include='all')
# Out:
#        STATION CODE LOCATIONS STATE  Temp D.O. (mg/l)    PH  \
# count          1991      1991  1991  1991        1991  1991
# unique          321       666   203   179         166   266
# top             NAN       NAN   NAN    28         6.8   7.2
# freq            122       184   761   241         118   138
# mean            NaN       NaN   NaN   NaN         NaN   NaN
# std             NaN       NaN   NaN   NaN         NaN   NaN
# min             NaN       NaN   NaN   NaN         NaN   NaN
# 25%             NaN       NaN   NaN   NaN         NaN   NaN
# 50%             NaN       NaN   NaN   NaN         NaN   NaN
# 75%             NaN       NaN   NaN   NaN         NaN   NaN
# max             NaN       NaN   NaN   NaN         NaN   NaN
#
#        CONDUCTIVITY (�mhos/cm) B.O.D. (mg/l) NITRATENAN N+ NITRITENANN (mg/l)  \
# count                     1991          1991                             1991
# unique                    1005           408                              507
# ...

# %%
print(water_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (�mhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
# ...

# %%
print(water_data.isnull().sum())
print(water_data['Temp'].unique())  # Replace 'Temp' with other column names to inspect
# Out:
# STATION CODE                        0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (�mhos/cm)             0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64
# ['30.6' '29.8' '29.5' '29.7' '30' '29.2' '29.6' '30.1' '27.8' '27.9'
#  '29.3' '29' '29.1' '28.7' '29.4' '28.3' '30.3' '30.5' '25.1' '27.4' '25'
#  '25.3' '26.1' '21.4' '27.1' '27.2' '27.3' '27' '22.6' '28.4' '28' '27.6'
#  '28.1' '28.6' '26.9' '23' '24.6' '25.7' '24.8' '27.5' '25.2' '29.9'
#  '26.7' '25.8' '26.4' '26' '23.6' '30.7' '28.2' '26.3' '26.6' '30.4'
#  '25.5' '28.9' '28.8' '28.5' '30.2' '30.8' '27.7' '31' '25.9' '26.5'
# ...

# %%
water_data['Temp'] = pd.to_numeric(water_data['Temp'], errors='coerce')  # Coerce invalid values to NaN

# %%
water_data.describe(include='all')
# Out:
#        STATION CODE LOCATIONS STATE         Temp D.O. (mg/l)    PH  \
# count          1991      1991  1991  1899.000000        1991  1991
# unique          321       666   203          NaN         166   266
# top             NAN       NAN   NAN          NaN         6.8   7.2
# freq            122       184   761          NaN         118   138
# mean            NaN       NaN   NaN    26.209814         NaN   NaN
# std             NaN       NaN   NaN     3.366388         NaN   NaN
# min             NaN       NaN   NaN    10.000000         NaN   NaN
# 25%             NaN       NaN   NaN    24.750000         NaN   NaN
# 50%             NaN       NaN   NaN    27.000000         NaN   NaN
# 75%             NaN       NaN   NaN    28.400000         NaN   NaN
# max             NaN       NaN   NaN    35.000000         NaN   NaN
#
#        CONDUCTIVITY (�mhos/cm) B.O.D. (mg/l) NITRATENAN N+ NITRITENANN (mg/l)  \
# count                     1991          1991                             1991
# ...

# %%
summary = water_data.describe()
print(summary)
# Out:
#               Temp         year
# count  1899.000000  1991.000000
# mean     26.209814  2010.038172
# std       3.366388     3.057333
# min      10.000000  2003.000000
# 25%      24.750000  2008.000000
# 50%      27.000000  2011.000000
# 75%      28.400000  2013.000000
# max      35.000000  2014.000000

# %%
water_data.duplicated().any()
# Out:
# np.True_

# %%
water_data.isnull().sum()
# Out:
# STATION CODE                         0
# LOCATIONS                            0
# STATE                                0
# Temp                                92
# D.O. (mg/l)                          0
# PH                                   0
# CONDUCTIVITY (�mhos/cm)              0
# B.O.D. (mg/l)                        0
# NITRATENAN N+ NITRITENANN (mg/l)     0
# FECAL COLIFORM (MPN/100ml)           0
# TOTAL COLIFORM (MPN/100ml)Mean       0
# year                                 0
# dtype: int64

# %%
null_df = water_data.isnull().sum().reset_index()
null_df.columns=['Column','Null_count']
null_df['%miss_value']=round(null_df['Null_count']/len(water_data),2)*100
null_df
# Out:
#                               Column  Null_count  %miss_value
# 0                       STATION CODE           0          0.0
# 1                          LOCATIONS           0          0.0
# 2                              STATE           0          0.0
# 3                               Temp          92          5.0
# 4                        D.O. (mg/l)           0          0.0
# 5                                 PH           0          0.0
# 6            CONDUCTIVITY (�mhos/cm)           0          0.0
# 7                      B.O.D. (mg/l)           0          0.0
# 8   NITRATENAN N+ NITRITENANN (mg/l)           0          0.0
# 9         FECAL COLIFORM (MPN/100ml)           0          0.0
# 10    TOTAL COLIFORM (MPN/100ml)Mean           0          0.0
# 11                              year           0          0.0

# %%
sns.heatmap(water_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
water_data['Temp'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
water_data['Temp']=water_data['Temp'].fillna(water_data['Temp'].mean())

# %%
water_data.isnull().sum()
# Out:
# STATION CODE                        0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (�mhos/cm)             0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %%
water_data.describe(include='all')
# Out:
#        STATION CODE LOCATIONS STATE         Temp D.O. (mg/l)    PH  \
# count          1991      1991  1991  1991.000000        1991  1991
# unique          321       666   203          NaN         166   266
# top             NAN       NAN   NAN          NaN         6.8   7.2
# freq            122       184   761          NaN         118   138
# mean            NaN       NaN   NaN    26.209814         NaN   NaN
# std             NaN       NaN   NaN     3.287652         NaN   NaN
# min             NaN       NaN   NaN    10.000000         NaN   NaN
# 25%             NaN       NaN   NaN    25.000000         NaN   NaN
# 50%             NaN       NaN   NaN    27.000000         NaN   NaN
# 75%             NaN       NaN   NaN    28.300000         NaN   NaN
# max             NaN       NaN   NaN    35.000000         NaN   NaN
#
#        CONDUCTIVITY (�mhos/cm) B.O.D. (mg/l) NITRATENAN N+ NITRITENANN (mg/l)  \
# count                     1991          1991                             1991
# ...

# %%
water_data.info()
print(water_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   float64
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (�mhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
# ...

# %%
water_data = water_data.select_dtypes(include=[float, int])

# %%
water_data = water_data.fillna(0)

# %%
corr_matrix = -water_data.corr()
print(corr_matrix)
# Out:
#           Temp      year
# Temp -1.000000  0.009576
# year  0.009576 -1.000000

# %%
corr_matrix=water_data.corr()
corr_matrix
# Out:
#           Temp      year
# Temp  1.000000 -0.009576
# year -0.009576  1.000000

# %%
plt.figure(figsize=(18, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
